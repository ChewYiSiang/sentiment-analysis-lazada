# %% [markdown]
# # Lazada App Reviews - Sentimental Analysis
# ### Data Source:
# This notebook uses sentimental analysis on Lazada's app reviews (Google store) from Kaggle:
# https://www.kaggle.com/datasets/bwandowando/lazada-app-reviews-from-google-store/data
#
# ### Objectives:
# - Find out what are the customers' sentiment towards Lazada's app.

# %% [markdown]
# #### Data Description:
# - Unnamed : Index
# - review_text : Customer review
# - review_rating : Customer rating ranging from 1-5
# - author_id : Customer id
# - author_name : Customer name
# - author_app_version : App version that customer uses
# - review_datetime_utc : Date and Time when customer posted their review
# - review_likes : The amount of likes a review has

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# If running on a fresh environment, uncomment the pip installs below.

# !pip install pandas numpy matplotlib seaborn scikit-learn nltk emoji wordcloud langdetect
# !pip install transformers torch --upgrade
# !pip install sentencepiece # required by some multilingual Transformer models
# !pip install --upgrade imbalanced-learn

# %%
import sklearn

import os, re, string, random
import numpy as np
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Text
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

import emoji
from wordcloud import WordCloud

import re
import string

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score
# from sklearn.pipeline import Pipeline
import nltk

# Resampling
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from collections import Counter

from imblearn.under_sampling import TomekLinks
from imblearn.combine import SMOTETomek

# Machine Learning Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from imblearn.pipeline import Pipeline as ImbPipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
import joblib # saving models
from sklearn.neighbors import NearestNeighbors

# Machine Learning Validation
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

import warnings
warnings.filterwarnings("ignore")

# Ensure NLTK assets
try:
    _ = stopwords.words("english")
except LookupError:
    nltk.download("stopwords")
try:
    _ = nltk.data.find("tokenizers/punkt")
except LookupError:
    nltk.download("punkt")
try:
    _ = nltk.data.find("sentiment/vader_lexicon.zip")
except LookupError:
    nltk.download("vader_lexicon")
    
nltk.download('punkt_tab')

sns.set_theme()
plt.rcParams["figure.dpi"] = 120
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\alsto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# loading dataset
df = pd.read_csv("LAZADA_REVIEWS.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                        review_text  \
# 0           0  This app is a big step in right direction - gr...
# 1           1  This is what I have been looking for. Now I ca...
# 2           2  Its a great way of shopping online. But please...
# 3           3                       Thanks lazada for this app!!
# 4           4                                        Good app ;)
#
#    review_rating              author_id    author_name author_app_version  \
# 0              5  109329*********902682  A Google user                1.0
# 1              5  109886*********190000  A Google user                1.0
# 2              1  114358*********899063  A Google user                1.0
# 3              5  108006*********600292  A Google user                1.0
# 4              5  110676*********237626  A Google user                1.0
#
#         review_datetime_utc  review_likes
# 0  2013-06-09T08:34:37.000Z             2
# 1  2013-06-09T09:29:25.000Z             0
# 2  2013-06-09T10:19:39.000Z             0
# 3  2013-06-10T02:24:14.000Z             0
# 4  2013-06-10T02:35:53.000Z             0

# %%
df.shape
# Out:
# (775323, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'review_text', 'review_rating', 'author_id',
#        'author_name', 'author_app_version', 'review_datetime_utc',
#        'review_likes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775323 entries, 0 to 775322
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           775323 non-null  int64
#  1   review_text          775018 non-null  object
#  2   review_rating        775323 non-null  int64
#  3   author_id            775195 non-null  object
#  4   author_name          775322 non-null  object
#  5   author_app_version   600912 non-null  object
#  6   review_datetime_utc  775323 non-null  object
#  7   review_likes         775323 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 47.3+ MB

# %% [markdown]
# ### **Follow up actions:**
# - Split up the dataset into training and testing dataset so there isn't a data leakage.
# - Are there authors who has too many comments over the others such that it can cause biasness in the app review?
# - review_text needs to convert to string dtype
# - review_rating will split into sentiment categories, 'positive', 'negative', 'neutral'

# %%
df[df['review_text'].duplicated()]
# Out:
#         Unnamed: 0 review_text  review_rating              author_id  \
# 67              67        Good              5  117004*********121943
# 103            103   Great app              5  103579*********094848
# 115            115        Nice              4  103463*********364007
# 123            123        Good              5  101472*********807948
# 132            132        good              4  104615*********588290
# ...            ...         ...            ...                    ...
# 775309      775309   very nice              5  102022*********273581
# 775312      775312        good              5  112571*********852590
# 775318      775318        nice              5  105611*********908291
# 775319      775319        Nice              5  108460*********801893
# 775322      775322        Good              5  104025*********727802
#
#           author_name author_app_version       review_datetime_utc  \
# 67      A Google user              1.0.1  2013-06-18T19:18:18.000Z
# 103     A Google user              1.0.2  2013-07-28T13:10:44.000Z
# 115     A Google user              1.0.2  2013-08-19T19:52:10.000Z
# 123     A Google user              1.0.2  2013-09-04T14:37:42.000Z
# 132     A Google user              2.0.1  2013-09-15T02:34:07.000Z
# ...               ...                ...                       ...
# 775309  A Google user             7.37.0  2023-11-13T14:19:40.000Z
# 775312  A Google user             7.37.0  2023-11-13T14:23:41.000Z
# 775318  A Google user                NaN  2023-11-13T14:35:46.000Z
# 775319  A Google user             7.37.0  2023-11-13T14:39:25.000Z
# 775322  A Google user                NaN  2023-11-13T14:45:41.000Z
#
#         review_likes
# 67                 0
# 103                0
# 115                0
# 123                0
# 132                0
# ...              ...
# 775309             0
# 775312             0
# 775318             0
# 775319             0
# 775322             0
#
# [353652 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# review_text               305
# review_rating               0
# author_id                 128
# author_name                 1
# author_app_version     174411
# review_datetime_utc         0
# review_likes                0
# dtype: int64

# %% [markdown]
# There are **duplicated** values in the review_text but it will be kept because the duplicated values are still needed for sentiment analysis and will not affect biasness.
#
# There are also **missing** values in the dataset. Since we will only be looking at review_text and review_rating, we will drop all the null values in review_text since there are only afew of them.

# %%
df['author_id'].value_counts().sort_values(ascending=False)
# Out:
# author_id
# 106224*********970971    2
# 108251*********386038    2
# 115385*********904547    2
# 104626*********394665    2
# 101496*********456412    2
#                         ..
# 114756*********724527    1
# 107455*********192107    1
# 107886*********152196    1
# 109467*********187285    1
# 104025*********727802    1
# Name: count, Length: 775103, dtype: int64

# %% [markdown]
# The most a customer commented was **2 comments** so we do not have to worry about a single customer making too many reviews which causes bias opinions towards the app.

# %%
# rating will be our dependent variable so we will need to classify them under positive, negative or neutral
    
def addSentiment(df):
    def rating_to_sentiment(r):
        if r >= 4: 
            return 'positive'
        elif r <= 2: 
            return 'negative'
        else: 
            return 'neutral'
    
    df['sentiment'] = df['review_rating'].apply(rating_to_sentiment)
    return df

addSentiment(df)
df.head()
# Out:
#    Unnamed: 0                                        review_text  \
# 0           0  This app is a big step in right direction - gr...
# 1           1  This is what I have been looking for. Now I ca...
# 2           2  Its a great way of shopping online. But please...
# 3           3                       Thanks lazada for this app!!
# 4           4                                        Good app ;)
#
#    review_rating              author_id    author_name author_app_version  \
# 0              5  109329*********902682  A Google user                1.0
# 1              5  109886*********190000  A Google user                1.0
# 2              1  114358*********899063  A Google user                1.0
# 3              5  108006*********600292  A Google user                1.0
# 4              5  110676*********237626  A Google user                1.0
#
#         review_datetime_utc  review_likes sentiment
# 0  2013-06-09T08:34:37.000Z             2  positive
# 1  2013-06-09T09:29:25.000Z             0  positive
# 2  2013-06-09T10:19:39.000Z             0  negative
# 3  2013-06-10T02:24:14.000Z             0  positive
# 4  2013-06-10T02:35:53.000Z             0  positive

# %%
sns.countplot(x='sentiment', data=df)
plt.show()

# %% [markdown]
# ##### Graph summary
# There is a huge imbalance in the classification of sentiments. 'Positive' is overwhelmingly higher than the rest and neutral is very scarce. Hence, to prevent imbalanced data, resampling will be needed.

# %%
# changing data type to string
def change_type(df):
    df['review_text'] = df['review_text'].astype('string')
    return df

change_type(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775323 entries, 0 to 775322
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           775323 non-null  int64
#  1   review_text          775018 non-null  string
#  2   review_rating        775323 non-null  int64
#  3   author_id            775195 non-null  object
#  4   author_name          775322 non-null  object
#  5   author_app_version   600912 non-null  object
#  6   review_datetime_utc  775323 non-null  object
#  7   review_likes         775323 non-null  int64
#  8   sentiment            775323 non-null  object
# dtypes: int64(3), object(5), string(1)
# memory usage: 53.2+ MB

# %%
# drop null values so we can split them up
def drop_null(df):
    df.dropna(subset=['review_text'], inplace=True)
    return df

drop_null(df)

# creating text_len to split up text into words and counting them
df['text_len'] = df['review_text'].apply(lambda x: len(x.split()))
    
clean_data(df)
print(df['text_len'].describe())
# Out:
# count    775018.000000
# mean          7.321471
# std          12.597606
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           7.000000
# max         379.000000
# Name: text_len, dtype: float64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# review_text                 0
# review_rating               0
# author_id                 119
# author_name                 1
# author_app_version     174296
# review_datetime_utc         0
# review_likes                0
# sentiment                   0
# text_len                    0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['text_len'], bins=50, kde=True) 
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### Summary of graph
# Average word count of a text is 7 words. However, there are some texts with high word counts, with the max being 379 words. Long texts can have multiple sentiments to it so it may confuse the model. To counter this, we will do normalisation to analyse the sentiment per sentence/paragraph.

# %% [markdown]
# ## **EDA Summary**:
# - 'sentiment' will be our dependent variable, derived from review_ratings.
# - 'review_text' will be used to analze the sentiment.
# - There are missing values in review_text which has already been dropped to analyse text lengths.
#
# ### Follow up actions:
# - Clean text
# - Balance classification data using resampling.
# - Normalize text length

# %% [markdown]
# # Data Preprocessing

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# review_text                 0
# review_rating               0
# author_id                 119
# author_name                 1
# author_app_version     174296
# review_datetime_utc         0
# review_likes                0
# sentiment                   0
# text_len                    0
# clean_text                  0
# dtype: int64

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
# stemmer = PorterStemmer()
def clean_text(text):
    text = text.lower() # lower case
    text = re.sub(r'http\S+|www\S+', '', text) # remove URLs
    text = re.sub(r'<.*?>', '', text) # remove HTML tags
    text = re.sub(r'@\w+', '', text)  # remove @mentions
    text = re.sub(r'#\w+', '', text)  # remove #hashtags
    text = re.sub(r'\d+', '', text) # remove numbers e.g. order ID, dates or order numbers
    text = text.translate(str.maketrans('', '', string.punctuation)) # remove punctuations (exclamation marks can indicate emotion, depends on use case)
    text = emoji.demojize(text) # change emoji into text emoji
    text = re.sub(r'(.)\1{2,}', r'\1\1', text) # normalize repeated characters, "goooood" to "good"

    # tokenization
    tokens = nltk.word_tokenize(text) # tokenize sentences into word tokens
    tokens = [w for w in tokens if w not in stop_words] # remove stopwords
    tokens = [lemmatizer.lemmatize(w) for w in tokens] # lemmatization, "running" to "run" to reduce vocab size. Slower than stem to understand deeper text analysis but costs more.
    # tokens = [stemmer.stem(w) for w in tokens] # stemming, either this or lemmatization, not both. Used for speed and scalability (less cost)

    return ' '.join(tokens)
    
def text_preprocessed(df):
    df = addSentiment(df)
    df = change_type(df)
    df = drop_null(df)

    df['clean_text'] = df['review_text'].apply(clean_text)
    
    # only cleaned text and sentiment is needed for this analysis
    return df[['clean_text']]

# df = clean_text(df)
df.head()
# Out:
#    Unnamed: 0                                        review_text  \
# 0           0  This app is a big step in right direction - gr...
# 1           1  This is what I have been looking for. Now I ca...
# 2           2  Its a great way of shopping online. But please...
# 3           3                       Thanks lazada for this app!!
# 4           4                                        Good app ;)
#
#    review_rating              author_id    author_name author_app_version  \
# 0              5  109329*********902682  A Google user                1.0
# 1              5  109886*********190000  A Google user                1.0
# 2              1  114358*********899063  A Google user                1.0
# 3              5  108006*********600292  A Google user                1.0
# 4              5  110676*********237626  A Google user                1.0
#
#         review_datetime_utc  review_likes sentiment
# 0  2013-06-09T08:34:37.000Z             2  positive
# 1  2013-06-09T09:29:25.000Z             0  positive
# 2  2013-06-09T10:19:39.000Z             0  negative
# 3  2013-06-10T02:24:14.000Z             0  positive
# 4  2013-06-10T02:35:53.000Z             0  positive

# %% [markdown]
# ## Summary of Data-Preprocessing

# %% [markdown]
# Created functions that can be implemented into pipeline at the end for a seamless workflow.
#
# For reference,
# - addSentiment(df)
# - text_preprocessed(df)

# %% [markdown]
# # Model Training and Evaluation

# %%
X = df['clean_text']
y = df['sentiment']

# Convert text to TF-IDF features
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1,2))
X_vec = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.3, random_state=RANDOM_SEED, stratify=y)

# %% [markdown]
# ##### Before balancing data:

# %%
print("Before Resampling:", Counter(y_train))
# Out:
# Before Resampling: Counter({'positive': 442448, 'negative': 78958, 'neutral': 21106})

# %%
# Undersample majority
rus = RandomUnderSampler(
    sampling_strategy={'positive': 200000, 'negative': 78958, 'neutral': 21106},  # target sizes
    random_state=42)
X_rus, y_rus = rus.fit_resample(X_train, y_train)
print("After undersampling:", Counter(y_rus))

# Oversample minority
smote = SMOTE(sampling_strategy='auto', random_state=42)  
X_bal, y_bal = smote.fit_resample(X_rus, y_rus)
print("After undersampling + oversampling:", Counter(y_bal))
# Out:
# After undersampling: Counter({'positive': 200000, 'negative': 78958, 'neutral': 21106})
# After undersampling + oversampling: Counter({'negative': 200000, 'neutral': 200000, 'positive': 200000})

# %%
sns.countplot(x=y_bal, data=df)
plt.show()

# %% [markdown]
# Now that we have balanced the data, we need to make sure all features are comparable, so standardization is needed so that the model can fairly decide which one is predictive.

# %%
# Fit on training data only to prevent data leakages
scaler = StandardScaler(with_mean=False)
X_train_scaled = scaler.fit_transform(X_bal)

# Apply the same transformation to test
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Logistic Regression (Baseline Model)
# TF-IDF reflects how important a word is to a document in a collection or corpus, often used to reflect the relevance of words.
# Logistic regression is a classification model which is suitable for multiclass sentiment analysis (positive, negative, neutral) and works well with TF-IDF.

# %%
# Example: Test 5 different C values with 5-fold cross-validation
log_reg_cv = LogisticRegressionCV(Cs=5, cv=5, random_state=42)

# %%
log_reg_cv.fit(X_train_scaled, y_bal)
# Out:
# LogisticRegressionCV(Cs=5, cv=5, random_state=42)

# %%
best_c = log_reg_cv.C_[0] # For binary classification, C_ is an array, take the first element
print(f"Best C value: {best_c}")
# Out:
# Best C value: 1.0

# %%
# lr model
lr_model = LogisticRegression(
    C=1, 
    penalty='l2', 
    max_iter=1000,
    multi_class='auto'
)
lr_model.fit(X_train_scaled, y_bal)
# Out:
# LogisticRegression(C=1, max_iter=1000)

# %%
# Bundle models into a dictionary
models = {
    "logistic": lr_model,
}

# Save all models to a single file
joblib.dump(models, "all_models.pkl")

# Load the dictionary of models
# loaded_models = joblib.load("all_models.pkl")

# Access individual models
# logistic_model = loaded_models["logistic"]
# do predictions after
# Out:
# ['all_models.pkl']

# %%
y_pred_lr = lr_model.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("Classification Report:\n", classification_report(y_test, y_pred_lr))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))
# Out:
# Accuracy: 0.7820486353040351
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.72      0.73      0.73     33840
#      neutral       0.09      0.40      0.15      9045
#     positive       0.96      0.81      0.88    189621
#
#     accuracy                           0.78    232506
#    macro avg       0.59      0.65      0.59    232506
# weighted avg       0.89      0.78      0.83    232506
#
# Confusion Matrix:
#  [[ 24749   6080   3011]
#  [  2188   3625   3232]
#  [  7219  28945 153457]]

# %% [markdown]
# #### Logistic Regression (Baseline Model) Performance
# - Accuracy of **0.78**

# %% [markdown]
# ### Naives Baye Model

# %%
# Naive Bayes model
nb = MultinomialNB()

# Hyperparameter grid
param_grid = {
    'alpha': [0.1, 0.5, 1.0, 5.0],      # Laplace smoothing
    'fit_prior': [True, False]          # Use class priors or not
}

# Grid search with 5 fold cross-validation
grid_search = GridSearchCV(nb, param_grid, cv=5, scoring='f1', n_jobs=-1)
grid_search.fit(X_train_scaled, y_bal)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'alpha': 0.1, 'fit_prior': True}

# %%
# nb model
nb_model = MultinomialNB(alpha=0.1, fit_prior=True)
nb_model.fit(X_train_scaled, y_bal)
# Out:
# MultinomialNB(alpha=0.1)

# %%
# Add nb model
# Load existing models
models = joblib.load("all_models.pkl")

# Add new model
models["naives_baye"] = nb_model


# 3. Save back to the same file
joblib.dump(models, "all_models.pkl")
# Out:
# ['all_models.pkl']

# %%
# # Evaluate nb model
y_pred_nb = nb_model.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred_nb))
print("Classification Report:\n", classification_report(y_test, y_pred_nb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_nb))
# Out:
# Accuracy: 0.7683672679414725
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.58      0.69      0.63     33840
#      neutral       0.11      0.43      0.18      9045
#     positive       0.96      0.80      0.87    189621
#
#     accuracy                           0.77    232506
#    macro avg       0.55      0.64      0.56    232506
# weighted avg       0.87      0.77      0.81    232506
#
# Confusion Matrix:
#  [[ 23206   7467   3167]
#  [  2074   3863   3108]
#  [ 14499  23541 151581]]

# %% [markdown]
# #### Comparing baseline model against naives baye model
# Baseline model had a prediction accuracy of **0.78**, while the naives bayes model had a prediction accuracy of **0.76**. Hence baseline model is still better.

# %% [markdown]
# ### SVM Model
# LinearSVC model will be used instead of SVC model as the SVC model is not optimal for the size of this dataset. I will be using SGDClassifier to track progress and use early stopping with the big dataset in mind.

# %%
# # linear SVM model
# linearsvm = LinearSVC(
#     tol=1e-3,       # tolerance for stopping, decrease if needed
#     max_iter=5000,  # increase if there is convergence warnings
#     dual=False      # faster when n_samples > n_features
# )

# # Hyperparameter grid
# param_grid = {
#     'C': [0.01, 0.1, 1, 10, 100],
#     'penalty': ['l2'],   # or add 'l1' if you want sparse solutions
#     'loss': ['squared_hinge', 'hinge']
# }

# # GridSearchCV for hyperparameter tuning

# grid_search = GridSearchCV(linearsvm, param_grid, cv=5, scoring='f1', n_jobs=-1)
# grid_search.fit(X_train_scaled, y_bal)

# # Best param
# print("Best parameters:", grid_search.best_params_)
# Out:
# Best parameters: {'C': 0.01, 'loss': 'squared_hinge', 'penalty': 'l2'}

# %%
# linear SVM model
from sklearn.linear_model import SGDClassifier

linearsvm = SGDClassifier(
        loss="hinge",        # hinge loss = linear SVM
        max_iter=1000,
        tol=1e-3,
        verbose=1,           # <-- print progress each epoch
    )

# Hyperparameter grid
param_grid = {
    'alpha': [1e-4, 1e-3, 1e-2],   # like 1/C in SVM
    'penalty': ['l2', 'l1'],
    'learning_rate': ['optimal', 'invscaling'],
}

# GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(linearsvm, param_grid, cv=5, scoring='f1', n_jobs=-1)
grid_search.fit(X_train_scaled, y_bal)

# Best param
print("Best parameters:", grid_search.best_params_)
# Out:
# -- Epoch 1
# Norm: 95.24, NNZs: 4988, Bias: -2.902053, T: 600000, Avg. loss: 50.993762
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 50.50, NNZs: 4993, Bias: -2.510166, T: 1200000, Avg. loss: 7.284720
# Total training time: 0.13 seconds.
# -- Epoch 3
# Norm: 34.75, NNZs: 4994, Bias: -2.215931, T: 1800000, Avg. loss: 4.408885
# Total training time: 0.19 seconds.
# -- Epoch 4
# Norm: 26.57, NNZs: 4994, Bias: -1.962286, T: 2400000, Avg. loss: 3.225908
# Total training time: 0.25 seconds.
# -- Epoch 5
# Norm: 21.52, NNZs: 4994, Bias: -1.760326, T: 3000000, Avg. loss: 2.553001
# Total training time: 0.31 seconds.
# -- Epoch 6
# Norm: 18.23, NNZs: 4994, Bias: -1.588095, T: 3600000, Avg. loss: 2.153699
# Total training time: 0.38 seconds.
# -- Epoch 7
# Norm: 16.02, NNZs: 4994, Bias: -1.437958, T: 4200000, Avg. loss: 1.866037
# Total training time: 0.44 seconds.
# -- Epoch 8
# Norm: 14.06, NNZs: 4994, Bias: -1.311635, T: 4800000, Avg. loss: 1.661307
# Total training time: 0.50 seconds.
# -- Epoch 9
# Norm: 12.79, NNZs: 4994, Bias: -1.204764, T: 5400000, Avg. loss: 1.497173
# Total training time: 0.56 seconds.
# -- Epoch 10
# Norm: 11.63, NNZs: 4994, Bias: -1.114916, T: 6000000, Avg. loss: 1.378683
# Total training time: 0.63 seconds.
# -- Epoch 11
# Norm: 10.75, NNZs: 4995, Bias: -1.039085, T: 6600000, Avg. loss: 1.273461
# Total training time: 0.69 seconds.
# -- Epoch 12
# Norm: 10.00, NNZs: 4996, Bias: -1.000302, T: 7200000, Avg. loss: 1.192041
# Total training time: 0.75 seconds.
# -- Epoch 13
# Norm: 9.31, NNZs: 4996, Bias: -0.999785, T: 7800000, Avg. loss: 1.121621
# Total training time: 0.82 seconds.
# -- Epoch 14
# Norm: 8.84, NNZs: 4996, Bias: -1.000211, T: 8400000, Avg. loss: 1.062422
# Total training time: 0.88 seconds.
# -- Epoch 15
# Norm: 8.30, NNZs: 4996, Bias: -1.000168, T: 9000000, Avg. loss: 1.013854
# Total training time: 0.94 seconds.
# -- Epoch 16
# Norm: 7.86, NNZs: 4996, Bias: -1.000109, T: 9600000, Avg. loss: 0.969006
# Total training time: 1.01 seconds.
# -- Epoch 17
# Norm: 7.54, NNZs: 4996, Bias: -1.000076, T: 10200000, Avg. loss: 0.931908
# Total training time: 1.07 seconds.
# -- Epoch 18
# Norm: 7.17, NNZs: 4996, Bias: -1.000001, T: 10800000, Avg. loss: 0.898516
# Total training time: 1.13 seconds.
# -- Epoch 19
# Norm: 6.81, NNZs: 4996, Bias: -1.000108, T: 11400000, Avg. loss: 0.865652
# Total training time: 1.19 seconds.
# -- Epoch 20
# Norm: 6.57, NNZs: 4996, Bias: -1.000055, T: 12000000, Avg. loss: 0.838898
# Total training time: 1.25 seconds.
# -- Epoch 21
# Norm: 6.32, NNZs: 4996, Bias: -0.999911, T: 12600000, Avg. loss: 0.814167
# Total training time: 1.32 seconds.
# -- Epoch 22
# Norm: 6.07, NNZs: 4996, Bias: -1.000235, T: 13200000, Avg. loss: 0.791546
# Total training time: 1.38 seconds.
# -- Epoch 23
# Norm: 5.90, NNZs: 4996, Bias: -0.999951, T: 13800000, Avg. loss: 0.772807
# Total training time: 1.44 seconds.
# -- Epoch 24
# Norm: 5.75, NNZs: 4996, Bias: -1.000024, T: 14400000, Avg. loss: 0.751464
# Total training time: 1.51 seconds.
# -- Epoch 25
# Norm: 5.51, NNZs: 4996, Bias: -1.000037, T: 15000000, Avg. loss: 0.736249
# Total training time: 1.57 seconds.
# -- Epoch 26
# Norm: 5.41, NNZs: 4996, Bias: -0.999985, T: 15600000, Avg. loss: 0.721194
# Total training time: 1.63 seconds.
# -- Epoch 27
# Norm: 5.22, NNZs: 4996, Bias: -1.000011, T: 16200000, Avg. loss: 0.706911
# Total training time: 1.70 seconds.
# -- Epoch 28
# Norm: 5.19, NNZs: 4996, Bias: -1.000018, T: 16800000, Avg. loss: 0.691579
# Total training time: 1.76 seconds.
# -- Epoch 29
# Norm: 4.96, NNZs: 4996, Bias: -0.999995, T: 17400000, Avg. loss: 0.680870
# Total training time: 1.82 seconds.
# -- Epoch 30
# Norm: 4.91, NNZs: 4996, Bias: -1.000062, T: 18000000, Avg. loss: 0.667654
# Total training time: 1.89 seconds.
# -- Epoch 31
# Norm: 4.72, NNZs: 4996, Bias: -1.000029, T: 18600000, Avg. loss: 0.658863
# Total training time: 1.95 seconds.
# -- Epoch 32
# Norm: 4.68, NNZs: 4996, Bias: -1.000008, T: 19200000, Avg. loss: 0.647687
# Total training time: 2.01 seconds.
# -- Epoch 33
# Norm: 4.55, NNZs: 4996, Bias: -0.999998, T: 19800000, Avg. loss: 0.639869
# Total training time: 2.07 seconds.
# -- Epoch 34
# Norm: 4.43, NNZs: 4996, Bias: -1.000028, T: 20400000, Avg. loss: 0.629228
# Total training time: 2.14 seconds.
# -- Epoch 35
# Norm: 4.35, NNZs: 4996, Bias: -1.000008, T: 21000000, Avg. loss: 0.622490
# Total training time: 2.20 seconds.
# -- Epoch 36
# Norm: 4.28, NNZs: 4996, Bias: -0.999985, T: 21600000, Avg. loss: 0.612374
# Total training time: 2.27 seconds.
# -- Epoch 37
# Norm: 4.21, NNZs: 4996, Bias: -1.000022, T: 22200000, Avg. loss: 0.607072
# Total training time: 2.33 seconds.
# -- Epoch 38
# Norm: 4.16, NNZs: 4996, Bias: -1.000031, T: 22800000, Avg. loss: 0.599609
# Total training time: 2.40 seconds.
# -- Epoch 39
# Norm: 4.06, NNZs: 4996, Bias: -1.000013, T: 23400000, Avg. loss: 0.592668
# Total training time: 2.46 seconds.
# -- Epoch 40
# Norm: 4.01, NNZs: 4996, Bias: -1.000017, T: 24000000, Avg. loss: 0.586176
# Total training time: 2.53 seconds.
# -- Epoch 41
# Norm: 3.91, NNZs: 4996, Bias: -1.000033, T: 24600000, Avg. loss: 0.581136
# Total training time: 2.59 seconds.
# -- Epoch 42
# Norm: 3.90, NNZs: 4996, Bias: -1.000033, T: 25200000, Avg. loss: 0.574980
# Total training time: 2.65 seconds.
# -- Epoch 43
# Norm: 3.83, NNZs: 4996, Bias: -0.999986, T: 25800000, Avg. loss: 0.570543
# Total training time: 2.72 seconds.
# -- Epoch 44
# Norm: 3.78, NNZs: 4996, Bias: -0.999929, T: 26400000, Avg. loss: 0.565221
# Total training time: 2.78 seconds.
# -- Epoch 45
# Norm: 3.72, NNZs: 4996, Bias: -1.000031, T: 27000000, Avg. loss: 0.559445
# Total training time: 2.85 seconds.
# -- Epoch 46
# Norm: 3.67, NNZs: 4996, Bias: -1.000005, T: 27600000, Avg. loss: 0.555278
# Total training time: 2.91 seconds.
# -- Epoch 47
# Norm: 3.60, NNZs: 4996, Bias: -0.999987, T: 28200000, Avg. loss: 0.550781
# Total training time: 2.98 seconds.
# -- Epoch 48
# Norm: 3.60, NNZs: 4996, Bias: -1.000089, T: 28800000, Avg. loss: 0.545005
# Total training time: 3.04 seconds.
# -- Epoch 49
# Norm: 3.57, NNZs: 4996, Bias: -1.000005, T: 29400000, Avg. loss: 0.542620
# Total training time: 3.10 seconds.
# -- Epoch 50
# Norm: 3.50, NNZs: 4996, Bias: -1.000015, T: 30000000, Avg. loss: 0.538455
# Total training time: 3.17 seconds.
# -- Epoch 51
# Norm: 3.43, NNZs: 4996, Bias: -1.000005, T: 30600000, Avg. loss: 0.534604
# Total training time: 3.23 seconds.
# -- Epoch 52
# Norm: 3.43, NNZs: 4996, Bias: -1.000037, T: 31200000, Avg. loss: 0.529654
# Total training time: 3.30 seconds.
# -- Epoch 53
# Norm: 3.37, NNZs: 4996, Bias: -1.000012, T: 31800000, Avg. loss: 0.528659
# Total training time: 3.36 seconds.
# -- Epoch 54
# Norm: 3.33, NNZs: 4996, Bias: -1.000005, T: 32400000, Avg. loss: 0.523469
# Total training time: 3.43 seconds.
# -- Epoch 55
# Norm: 3.30, NNZs: 4996, Bias: -1.000096, T: 33000000, Avg. loss: 0.520292
# Total training time: 3.49 seconds.
# -- Epoch 56
# Norm: 3.27, NNZs: 4996, Bias: -1.000003, T: 33600000, Avg. loss: 0.517236
# Total training time: 3.56 seconds.
# -- Epoch 57
# Norm: 3.24, NNZs: 4996, Bias: -1.000000, T: 34200000, Avg. loss: 0.515067
# Total training time: 3.62 seconds.
# -- Epoch 58
# Norm: 3.21, NNZs: 4996, Bias: -0.999985, T: 34800000, Avg. loss: 0.510297
# Total training time: 3.68 seconds.
# -- Epoch 59
# Norm: 3.19, NNZs: 4996, Bias: -1.000011, T: 35400000, Avg. loss: 0.509381
# Total training time: 3.75 seconds.
# -- Epoch 60
# Norm: 3.16, NNZs: 4996, Bias: -1.000000, T: 36000000, Avg. loss: 0.507782
# Total training time: 3.82 seconds.
# -- Epoch 61
# Norm: 3.12, NNZs: 4996, Bias: -1.000025, T: 36600000, Avg. loss: 0.502563
# Total training time: 3.88 seconds.
# -- Epoch 62
# Norm: 3.11, NNZs: 4996, Bias: -0.999968, T: 37200000, Avg. loss: 0.501026
# Total training time: 3.95 seconds.
# -- Epoch 63
# Norm: 3.08, NNZs: 4996, Bias: -0.999931, T: 37800000, Avg. loss: 0.498636
# Total training time: 4.02 seconds.
# -- Epoch 64
# Norm: 3.07, NNZs: 4996, Bias: -1.000003, T: 38400000, Avg. loss: 0.496124
# Total training time: 4.09 seconds.
# -- Epoch 65
# Norm: 3.03, NNZs: 4996, Bias: -0.999987, T: 39000000, Avg. loss: 0.495359
# Total training time: 4.16 seconds.
# -- Epoch 66
# Norm: 3.01, NNZs: 4996, Bias: -0.999993, T: 39600000, Avg. loss: 0.490874
# Total training time: 4.23 seconds.
# -- Epoch 67
# Norm: 2.98, NNZs: 4996, Bias: -0.999980, T: 40200000, Avg. loss: 0.489173
# Total training time: 4.30 seconds.
# -- Epoch 68
# Norm: 2.96, NNZs: 4996, Bias: -0.999990, T: 40800000, Avg. loss: 0.486720
# Total training time: 4.37 seconds.
# -- Epoch 69
# Norm: 2.95, NNZs: 4996, Bias: -0.999979, T: 41400000, Avg. loss: 0.485585
# Total training time: 4.43 seconds.
# -- Epoch 70
# Norm: 2.95, NNZs: 4996, Bias: -1.000036, T: 42000000, Avg. loss: 0.483198
# Total training time: 4.50 seconds.
# -- Epoch 71
# Norm: 2.91, NNZs: 4996, Bias: -0.999960, T: 42600000, Avg. loss: 0.481394
# Total training time: 4.57 seconds.
# -- Epoch 72
# Norm: 2.87, NNZs: 4996, Bias: -0.999996, T: 43200000, Avg. loss: 0.479934
# Total training time: 4.64 seconds.
# -- Epoch 73
# Norm: 2.86, NNZs: 4996, Bias: -1.000023, T: 43800000, Avg. loss: 0.478059
# Total training time: 4.70 seconds.
# -- Epoch 74
# Norm: 2.85, NNZs: 4996, Bias: -0.999989, T: 44400000, Avg. loss: 0.476794
# Total training time: 4.77 seconds.
# -- Epoch 75
# Norm: 2.82, NNZs: 4996, Bias: -0.999985, T: 45000000, Avg. loss: 0.474945
# Total training time: 4.84 seconds.
# -- Epoch 76
# Norm: 2.80, NNZs: 4996, Bias: -1.000016, T: 45600000, Avg. loss: 0.473807
# Total training time: 4.90 seconds.
# -- Epoch 77
# Norm: 2.78, NNZs: 4996, Bias: -0.999987, T: 46200000, Avg. loss: 0.471955
# Total training time: 4.97 seconds.
# -- Epoch 78
# Norm: 2.77, NNZs: 4996, Bias: -0.999941, T: 46800000, Avg. loss: 0.469553
# Total training time: 5.04 seconds.
# -- Epoch 79
# Norm: 2.76, NNZs: 4996, Bias: -0.999979, T: 47400000, Avg. loss: 0.468238
# Total training time: 5.11 seconds.
# -- Epoch 80
# Norm: 2.75, NNZs: 4996, Bias: -1.000025, T: 48000000, Avg. loss: 0.466708
# Total training time: 5.18 seconds.
# -- Epoch 81
# Norm: 2.73, NNZs: 4996, Bias: -0.999945, T: 48600000, Avg. loss: 0.465141
# Total training time: 5.25 seconds.
# -- Epoch 82
# Norm: 2.71, NNZs: 4996, Bias: -0.999968, T: 49200000, Avg. loss: 0.463623
# Total training time: 5.32 seconds.
# -- Epoch 83
# Norm: 2.71, NNZs: 4996, Bias: -0.999974, T: 49800000, Avg. loss: 0.462810
# Total training time: 5.39 seconds.
# -- Epoch 84
# Norm: 2.68, NNZs: 4996, Bias: -0.999957, T: 50400000, Avg. loss: 0.462196
# Total training time: 5.47 seconds.
# -- Epoch 85
# Norm: 2.66, NNZs: 4996, Bias: -0.999995, T: 51000000, Avg. loss: 0.459837
# Total training time: 5.54 seconds.
# -- Epoch 86
# Norm: 2.65, NNZs: 4996, Bias: -0.999977, T: 51600000, Avg. loss: 0.458621
# Total training time: 5.61 seconds.
# -- Epoch 87
# Norm: 2.64, NNZs: 4996, Bias: -1.000002, T: 52200000, Avg. loss: 0.457740
# Total training time: 5.68 seconds.
# -- Epoch 88
# Norm: 2.64, NNZs: 4996, Bias: -1.000001, T: 52800000, Avg. loss: 0.456225
# Total training time: 5.76 seconds.
# -- Epoch 89
# Norm: 2.63, NNZs: 4996, Bias: -1.000023, T: 53400000, Avg. loss: 0.455003
# Total training time: 5.83 seconds.
# -- Epoch 90
# Norm: 2.60, NNZs: 4996, Bias: -0.999999, T: 54000000, Avg. loss: 0.454281
# Total training time: 5.90 seconds.
# -- Epoch 91
# Norm: 2.60, NNZs: 4996, Bias: -0.999997, T: 54600000, Avg. loss: 0.453082
# Total training time: 5.97 seconds.
# -- Epoch 92
# Norm: 2.58, NNZs: 4996, Bias: -1.000028, T: 55200000, Avg. loss: 0.453263
# Total training time: 6.04 seconds.
# -- Epoch 93
# Norm: 2.55, NNZs: 4996, Bias: -0.999999, T: 55800000, Avg. loss: 0.450879
# Total training time: 6.12 seconds.
# -- Epoch 94
# Norm: 2.54, NNZs: 4996, Bias: -1.000006, T: 56400000, Avg. loss: 0.449837
# Total training time: 6.19 seconds.
# -- Epoch 95
# Norm: 2.53, NNZs: 4996, Bias: -0.999997, T: 57000000, Avg. loss: 0.448746
# Total training time: 6.26 seconds.
# -- Epoch 96
# Norm: 2.54, NNZs: 4996, Bias: -1.000011, T: 57600000, Avg. loss: 0.446989
# Total training time: 6.35 seconds.
# -- Epoch 97
# Norm: 2.52, NNZs: 4996, Bias: -0.999992, T: 58200000, Avg. loss: 0.446487
# Total training time: 6.42 seconds.
# -- Epoch 98
# Norm: 2.53, NNZs: 4996, Bias: -1.000011, T: 58800000, Avg. loss: 0.445691
# Total training time: 6.49 seconds.
# -- Epoch 99
# Norm: 2.51, NNZs: 4996, Bias: -0.999965, T: 59400000, Avg. loss: 0.445030
# Total training time: 6.55 seconds.
# -- Epoch 100
# Norm: 2.50, NNZs: 4996, Bias: -1.000001, T: 60000000, Avg. loss: 0.443134
# Total training time: 6.62 seconds.
# -- Epoch 101
# Norm: 2.49, NNZs: 4996, Bias: -0.999999, T: 60600000, Avg. loss: 0.442729
# Total training time: 6.69 seconds.
# -- Epoch 102
# Norm: 2.46, NNZs: 4996, Bias: -1.000002, T: 61200000, Avg. loss: 0.442534
# Total training time: 6.75 seconds.
# -- Epoch 103
# Norm: 2.47, NNZs: 4996, Bias: -1.000007, T: 61800000, Avg. loss: 0.440653
# Total training time: 6.82 seconds.
# -- Epoch 104
# Norm: 2.46, NNZs: 4996, Bias: -1.000010, T: 62400000, Avg. loss: 0.440104
# Total training time: 6.88 seconds.
# -- Epoch 105
# Norm: 2.45, NNZs: 4996, Bias: -0.999999, T: 63000000, Avg. loss: 0.439005
# Total training time: 6.95 seconds.
# -- Epoch 106
# Norm: 2.43, NNZs: 4996, Bias: -1.000068, T: 63600000, Avg. loss: 0.438749
# Total training time: 7.02 seconds.
# -- Epoch 107
# Norm: 2.43, NNZs: 4996, Bias: -1.000005, T: 64200000, Avg. loss: 0.438717
# Total training time: 7.08 seconds.
# -- Epoch 108
# Norm: 2.41, NNZs: 4996, Bias: -1.000007, T: 64800000, Avg. loss: 0.437148
# Total training time: 7.15 seconds.
# -- Epoch 109
# Norm: 2.41, NNZs: 4996, Bias: -1.000001, T: 65400000, Avg. loss: 0.435703
# Total training time: 7.21 seconds.
# -- Epoch 110
# Norm: 2.40, NNZs: 4996, Bias: -0.999961, T: 66000000, Avg. loss: 0.435748
# Total training time: 7.28 seconds.
# -- Epoch 111
# Norm: 2.41, NNZs: 4996, Bias: -0.999975, T: 66600000, Avg. loss: 0.435152
# Total training time: 7.35 seconds.
# -- Epoch 112
# Norm: 2.39, NNZs: 4996, Bias: -1.000021, T: 67200000, Avg. loss: 0.433343
# Total training time: 7.43 seconds.
# -- Epoch 113
# Norm: 2.38, NNZs: 4996, Bias: -1.000009, T: 67800000, Avg. loss: 0.432974
# Total training time: 7.50 seconds.
# -- Epoch 114
# Norm: 2.37, NNZs: 4996, Bias: -1.000001, T: 68400000, Avg. loss: 0.432832
# Total training time: 7.57 seconds.
# -- Epoch 115
# Norm: 2.35, NNZs: 4996, Bias: -0.999983, T: 69000000, Avg. loss: 0.432431
# Total training time: 7.65 seconds.
# -- Epoch 116
# Norm: 2.34, NNZs: 4996, Bias: -1.000005, T: 69600000, Avg. loss: 0.431628
# Total training time: 7.72 seconds.
# -- Epoch 117
# Norm: 2.35, NNZs: 4996, Bias: -0.999995, T: 70200000, Avg. loss: 0.431239
# Total training time: 7.78 seconds.
# Convergence after 117 epochs took 7.78 seconds
# -- Epoch 1
# Norm: 88.66, NNZs: 4992, Bias: 0.997685, T: 600000, Avg. loss: 58.461588
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 46.83, NNZs: 4996, Bias: 0.999714, T: 1200000, Avg. loss: 8.584527
# Total training time: 0.13 seconds.
# -- Epoch 3
# Norm: 32.25, NNZs: 4996, Bias: 0.999728, T: 1800000, Avg. loss: 5.219434
# Total training time: 0.19 seconds.
# -- Epoch 4
# Norm: 24.84, NNZs: 4997, Bias: 0.999735, T: 2400000, Avg. loss: 3.855222
# Total training time: 0.26 seconds.
# -- Epoch 5
# Norm: 20.48, NNZs: 4997, Bias: 0.999980, T: 3000000, Avg. loss: 3.103792
# Total training time: 0.33 seconds.
# -- Epoch 6
# Norm: 17.25, NNZs: 4997, Bias: 0.996743, T: 3600000, Avg. loss: 2.630521
# Total training time: 0.39 seconds.
# -- Epoch 7
# Norm: 14.99, NNZs: 4997, Bias: 0.998663, T: 4200000, Avg. loss: 2.308346
# Total training time: 0.46 seconds.
# -- Epoch 8
# Norm: 13.48, NNZs: 4997, Bias: 0.999450, T: 4800000, Avg. loss: 2.080742
# Total training time: 0.53 seconds.
# -- Epoch 9
# Norm: 12.18, NNZs: 4997, Bias: 0.999099, T: 5400000, Avg. loss: 1.894175
# Total training time: 0.60 seconds.
# -- Epoch 10
# Norm: 11.20, NNZs: 4997, Bias: 0.999084, T: 6000000, Avg. loss: 1.754885
# Total training time: 0.66 seconds.
# -- Epoch 11
# Norm: 10.39, NNZs: 4997, Bias: 0.999040, T: 6600000, Avg. loss: 1.635256
# Total training time: 0.73 seconds.
# -- Epoch 12
# Norm: 9.66, NNZs: 4997, Bias: 1.000093, T: 7200000, Avg. loss: 1.542805
# Total training time: 0.80 seconds.
# -- Epoch 13
# Norm: 9.13, NNZs: 4997, Bias: 0.999196, T: 7800000, Avg. loss: 1.459529
# Total training time: 0.87 seconds.
# -- Epoch 14
# Norm: 8.53, NNZs: 4997, Bias: 0.999340, T: 8400000, Avg. loss: 1.393177
# Total training time: 0.93 seconds.
# -- Epoch 15
# Norm: 8.04, NNZs: 4997, Bias: 0.999321, T: 9000000, Avg. loss: 1.340414
# Total training time: 1.00 seconds.
# -- Epoch 16
# Norm: 7.71, NNZs: 4997, Bias: 0.996214, T: 9600000, Avg. loss: 1.282140
# Total training time: 1.07 seconds.
# -- Epoch 17
# Norm: 7.39, NNZs: 4997, Bias: 0.997793, T: 10200000, Avg. loss: 1.240851
# Total training time: 1.14 seconds.
# -- Epoch 18
# Norm: 7.07, NNZs: 4997, Bias: 0.997708, T: 10800000, Avg. loss: 1.201512
# Total training time: 1.21 seconds.
# -- Epoch 19
# Norm: 6.77, NNZs: 4997, Bias: 0.997291, T: 11400000, Avg. loss: 1.166389
# Total training time: 1.27 seconds.
# -- Epoch 20
# Norm: 6.53, NNZs: 4997, Bias: 0.995484, T: 12000000, Avg. loss: 1.138317
# Total training time: 1.34 seconds.
# -- Epoch 21
# Norm: 6.29, NNZs: 4997, Bias: 0.993531, T: 12600000, Avg. loss: 1.109443
# Total training time: 1.41 seconds.
# -- Epoch 22
# Norm: 6.11, NNZs: 4997, Bias: 0.990779, T: 13200000, Avg. loss: 1.082248
# Total training time: 1.48 seconds.
# -- Epoch 23
# Norm: 5.92, NNZs: 4997, Bias: 0.986824, T: 13800000, Avg. loss: 1.058271
# Total training time: 1.55 seconds.
# -- Epoch 24
# Norm: 5.75, NNZs: 4997, Bias: 0.983756, T: 14400000, Avg. loss: 1.039532
# Total training time: 1.62 seconds.
# -- Epoch 25
# Norm: 5.61, NNZs: 4997, Bias: 0.980977, T: 15000000, Avg. loss: 1.019746
# Total training time: 1.68 seconds.
# -- Epoch 26
# Norm: 5.45, NNZs: 4997, Bias: 0.978281, T: 15600000, Avg. loss: 1.000165
# Total training time: 1.75 seconds.
# -- Epoch 27
# Norm: 5.33, NNZs: 4997, Bias: 0.974638, T: 16200000, Avg. loss: 0.983038
# Total training time: 1.82 seconds.
# -- Epoch 28
# Norm: 5.21, NNZs: 4997, Bias: 0.970870, T: 16800000, Avg. loss: 0.969831
# Total training time: 1.89 seconds.
# -- Epoch 29
# Norm: 5.09, NNZs: 4997, Bias: 0.968030, T: 17400000, Avg. loss: 0.954424
# Total training time: 1.96 seconds.
# -- Epoch 30
# Norm: 4.97, NNZs: 4997, Bias: 0.963895, T: 18000000, Avg. loss: 0.941365
# Total training time: 2.03 seconds.
# -- Epoch 31
# Norm: 4.90, NNZs: 4997, Bias: 0.961250, T: 18600000, Avg. loss: 0.927482
# Total training time: 2.10 seconds.
# -- Epoch 32
# Norm: 4.81, NNZs: 4997, Bias: 0.957891, T: 19200000, Avg. loss: 0.916609
# Total training time: 2.17 seconds.
# -- Epoch 33
# Norm: 4.72, NNZs: 4997, Bias: 0.954310, T: 19800000, Avg. loss: 0.906552
# Total training time: 2.23 seconds.
# -- Epoch 34
# Norm: 4.61, NNZs: 4997, Bias: 0.951062, T: 20400000, Avg. loss: 0.896695
# Total training time: 2.30 seconds.
# -- Epoch 35
# Norm: 4.55, NNZs: 4997, Bias: 0.949133, T: 21000000, Avg. loss: 0.887539
# Total training time: 2.37 seconds.
# -- Epoch 36
# Norm: 4.50, NNZs: 4997, Bias: 0.946251, T: 21600000, Avg. loss: 0.878480
# Total training time: 2.44 seconds.
# -- Epoch 37
# Norm: 4.40, NNZs: 4997, Bias: 0.944504, T: 22200000, Avg. loss: 0.869731
# Total training time: 2.51 seconds.
# -- Epoch 38
# Norm: 4.36, NNZs: 4997, Bias: 0.941881, T: 22800000, Avg. loss: 0.861922
# Total training time: 2.57 seconds.
# -- Epoch 39
# Norm: 4.25, NNZs: 4997, Bias: 0.939060, T: 23400000, Avg. loss: 0.855719
# Total training time: 2.64 seconds.
# -- Epoch 40
# Norm: 4.25, NNZs: 4997, Bias: 0.936400, T: 24000000, Avg. loss: 0.848619
# Total training time: 2.71 seconds.
# -- Epoch 41
# Norm: 4.16, NNZs: 4997, Bias: 0.934633, T: 24600000, Avg. loss: 0.840075
# Total training time: 2.78 seconds.
# -- Epoch 42
# Norm: 4.12, NNZs: 4997, Bias: 0.932722, T: 25200000, Avg. loss: 0.834655
# Total training time: 2.84 seconds.
# -- Epoch 43
# Norm: 4.07, NNZs: 4997, Bias: 0.930096, T: 25800000, Avg. loss: 0.827625
# Total training time: 2.91 seconds.
# -- Epoch 44
# Norm: 4.02, NNZs: 4997, Bias: 0.927262, T: 26400000, Avg. loss: 0.822179
# Total training time: 2.98 seconds.
# -- Epoch 45
# Norm: 3.98, NNZs: 4997, Bias: 0.924559, T: 27000000, Avg. loss: 0.815217
# Total training time: 3.05 seconds.
# -- Epoch 46
# Norm: 3.93, NNZs: 4997, Bias: 0.922994, T: 27600000, Avg. loss: 0.810893
# Total training time: 3.11 seconds.
# -- Epoch 47
# Norm: 3.89, NNZs: 4997, Bias: 0.920562, T: 28200000, Avg. loss: 0.806558
# Total training time: 3.19 seconds.
# -- Epoch 48
# Norm: 3.85, NNZs: 4997, Bias: 0.918339, T: 28800000, Avg. loss: 0.801362
# Total training time: 3.26 seconds.
# -- Epoch 49
# Norm: 3.82, NNZs: 4997, Bias: 0.916325, T: 29400000, Avg. loss: 0.795499
# Total training time: 3.33 seconds.
# -- Epoch 50
# Norm: 3.73, NNZs: 4997, Bias: 0.914773, T: 30000000, Avg. loss: 0.791954
# Total training time: 3.40 seconds.
# -- Epoch 51
# Norm: 3.71, NNZs: 4997, Bias: 0.912691, T: 30600000, Avg. loss: 0.786808
# Total training time: 3.46 seconds.
# -- Epoch 52
# Norm: 3.70, NNZs: 4997, Bias: 0.911518, T: 31200000, Avg. loss: 0.781700
# Total training time: 3.53 seconds.
# -- Epoch 53
# Norm: 3.66, NNZs: 4997, Bias: 0.909662, T: 31800000, Avg. loss: 0.778560
# Total training time: 3.60 seconds.
# -- Epoch 54
# Norm: 3.63, NNZs: 4997, Bias: 0.907455, T: 32400000, Avg. loss: 0.775253
# Total training time: 3.67 seconds.
# -- Epoch 55
# Norm: 3.60, NNZs: 4997, Bias: 0.905818, T: 33000000, Avg. loss: 0.771755
# Total training time: 3.74 seconds.
# -- Epoch 56
# Norm: 3.56, NNZs: 4997, Bias: 0.903690, T: 33600000, Avg. loss: 0.767418
# Total training time: 3.81 seconds.
# -- Epoch 57
# Norm: 3.55, NNZs: 4997, Bias: 0.901919, T: 34200000, Avg. loss: 0.764229
# Total training time: 3.88 seconds.
# -- Epoch 58
# Norm: 3.51, NNZs: 4997, Bias: 0.900162, T: 34800000, Avg. loss: 0.761443
# Total training time: 3.96 seconds.
# -- Epoch 59
# Norm: 3.48, NNZs: 4997, Bias: 0.898498, T: 35400000, Avg. loss: 0.758713
# Total training time: 4.03 seconds.
# -- Epoch 60
# Norm: 3.48, NNZs: 4997, Bias: 0.897103, T: 36000000, Avg. loss: 0.755905
# Total training time: 4.10 seconds.
# -- Epoch 61
# Norm: 3.43, NNZs: 4997, Bias: 0.895478, T: 36600000, Avg. loss: 0.752571
# Total training time: 4.17 seconds.
# -- Epoch 62
# Norm: 3.42, NNZs: 4997, Bias: 0.893985, T: 37200000, Avg. loss: 0.748461
# Total training time: 4.24 seconds.
# -- Epoch 63
# Norm: 3.40, NNZs: 4997, Bias: 0.892626, T: 37800000, Avg. loss: 0.746783
# Total training time: 4.31 seconds.
# -- Epoch 64
# Norm: 3.39, NNZs: 4997, Bias: 0.891272, T: 38400000, Avg. loss: 0.742711
# Total training time: 4.38 seconds.
# -- Epoch 65
# Norm: 3.36, NNZs: 4997, Bias: 0.889733, T: 39000000, Avg. loss: 0.741774
# Total training time: 4.45 seconds.
# -- Epoch 66
# Norm: 3.33, NNZs: 4997, Bias: 0.888760, T: 39600000, Avg. loss: 0.738794
# Total training time: 4.52 seconds.
# -- Epoch 67
# Norm: 3.30, NNZs: 4997, Bias: 0.887493, T: 40200000, Avg. loss: 0.737337
# Total training time: 4.60 seconds.
# -- Epoch 68
# Norm: 3.29, NNZs: 4997, Bias: 0.886113, T: 40800000, Avg. loss: 0.732636
# Total training time: 4.67 seconds.
# -- Epoch 69
# Norm: 3.27, NNZs: 4997, Bias: 0.884799, T: 41400000, Avg. loss: 0.731151
# Total training time: 4.74 seconds.
# -- Epoch 70
# Norm: 3.26, NNZs: 4997, Bias: 0.883418, T: 42000000, Avg. loss: 0.728669
# Total training time: 4.81 seconds.
# -- Epoch 71
# Norm: 3.25, NNZs: 4997, Bias: 0.882007, T: 42600000, Avg. loss: 0.727904
# Total training time: 4.88 seconds.
# -- Epoch 72
# Norm: 3.22, NNZs: 4997, Bias: 0.881044, T: 43200000, Avg. loss: 0.725752
# Total training time: 4.95 seconds.
# -- Epoch 73
# Norm: 3.20, NNZs: 4997, Bias: 0.879977, T: 43800000, Avg. loss: 0.723613
# Total training time: 5.02 seconds.
# -- Epoch 74
# Norm: 3.20, NNZs: 4997, Bias: 0.878913, T: 44400000, Avg. loss: 0.720162
# Total training time: 5.10 seconds.
# -- Epoch 75
# Norm: 3.17, NNZs: 4997, Bias: 0.878087, T: 45000000, Avg. loss: 0.719972
# Total training time: 5.17 seconds.
# -- Epoch 76
# Norm: 3.17, NNZs: 4997, Bias: 0.877224, T: 45600000, Avg. loss: 0.716792
# Total training time: 5.25 seconds.
# -- Epoch 77
# Norm: 3.13, NNZs: 4997, Bias: 0.876235, T: 46200000, Avg. loss: 0.715013
# Total training time: 5.32 seconds.
# -- Epoch 78
# Norm: 3.13, NNZs: 4997, Bias: 0.875069, T: 46800000, Avg. loss: 0.712960
# Total training time: 5.39 seconds.
# -- Epoch 79
# Norm: 3.10, NNZs: 4997, Bias: 0.874022, T: 47400000, Avg. loss: 0.711507
# Total training time: 5.46 seconds.
# -- Epoch 80
# Norm: 3.12, NNZs: 4997, Bias: 0.872781, T: 48000000, Avg. loss: 0.710390
# Total training time: 5.53 seconds.
# -- Epoch 81
# Norm: 3.09, NNZs: 4997, Bias: 0.871741, T: 48600000, Avg. loss: 0.708126
# Total training time: 5.60 seconds.
# -- Epoch 82
# Norm: 3.08, NNZs: 4997, Bias: 0.870977, T: 49200000, Avg. loss: 0.706773
# Total training time: 5.68 seconds.
# -- Epoch 83
# Norm: 3.06, NNZs: 4997, Bias: 0.870198, T: 49800000, Avg. loss: 0.705968
# Total training time: 5.76 seconds.
# -- Epoch 84
# Norm: 3.05, NNZs: 4997, Bias: 0.869084, T: 50400000, Avg. loss: 0.704295
# Total training time: 5.83 seconds.
# -- Epoch 85
# Norm: 3.05, NNZs: 4997, Bias: 0.868264, T: 51000000, Avg. loss: 0.702387
# Total training time: 5.90 seconds.
# -- Epoch 86
# Norm: 3.04, NNZs: 4997, Bias: 0.867104, T: 51600000, Avg. loss: 0.700466
# Total training time: 5.97 seconds.
# -- Epoch 87
# Norm: 3.01, NNZs: 4997, Bias: 0.865973, T: 52200000, Avg. loss: 0.699961
# Total training time: 6.05 seconds.
# -- Epoch 88
# Norm: 3.01, NNZs: 4997, Bias: 0.864999, T: 52800000, Avg. loss: 0.698522
# Total training time: 6.12 seconds.
# -- Epoch 89
# Norm: 3.00, NNZs: 4997, Bias: 0.864017, T: 53400000, Avg. loss: 0.695810
# Total training time: 6.20 seconds.
# -- Epoch 90
# Norm: 2.98, NNZs: 4997, Bias: 0.863064, T: 54000000, Avg. loss: 0.695990
# Total training time: 6.27 seconds.
# -- Epoch 91
# Norm: 2.97, NNZs: 4997, Bias: 0.862239, T: 54600000, Avg. loss: 0.694405
# Total training time: 6.34 seconds.
# -- Epoch 92
# Norm: 2.96, NNZs: 4997, Bias: 0.861465, T: 55200000, Avg. loss: 0.694088
# Total training time: 6.42 seconds.
# -- Epoch 93
# Norm: 2.95, NNZs: 4997, Bias: 0.860397, T: 55800000, Avg. loss: 0.691677
# Total training time: 6.49 seconds.
# -- Epoch 94
# Norm: 2.94, NNZs: 4997, Bias: 0.859734, T: 56400000, Avg. loss: 0.691267
# Total training time: 6.57 seconds.
# -- Epoch 95
# Norm: 2.93, NNZs: 4997, Bias: 0.859213, T: 57000000, Avg. loss: 0.689823
# Total training time: 6.65 seconds.
# -- Epoch 96
# Norm: 2.92, NNZs: 4997, Bias: 0.858308, T: 57600000, Avg. loss: 0.688235
# Total training time: 6.72 seconds.
# -- Epoch 97
# Norm: 2.91, NNZs: 4997, Bias: 0.857592, T: 58200000, Avg. loss: 0.687002
# Total training time: 6.80 seconds.
# -- Epoch 98
# Norm: 2.90, NNZs: 4997, Bias: 0.856915, T: 58800000, Avg. loss: 0.686115
# Total training time: 6.87 seconds.
# -- Epoch 99
# Norm: 2.89, NNZs: 4997, Bias: 0.856088, T: 59400000, Avg. loss: 0.684900
# Total training time: 6.95 seconds.
# -- Epoch 100
# Norm: 2.89, NNZs: 4997, Bias: 0.855316, T: 60000000, Avg. loss: 0.683862
# Total training time: 7.02 seconds.
# -- Epoch 101
# Norm: 2.88, NNZs: 4997, Bias: 0.854493, T: 60600000, Avg. loss: 0.683416
# Total training time: 7.09 seconds.
# -- Epoch 102
# Norm: 2.87, NNZs: 4997, Bias: 0.853730, T: 61200000, Avg. loss: 0.681268
# Total training time: 7.17 seconds.
# -- Epoch 103
# Norm: 2.86, NNZs: 4997, Bias: 0.853074, T: 61800000, Avg. loss: 0.680450
# Total training time: 7.24 seconds.
# -- Epoch 104
# Norm: 2.86, NNZs: 4997, Bias: 0.852475, T: 62400000, Avg. loss: 0.679515
# Total training time: 7.31 seconds.
# -- Epoch 105
# Norm: 2.86, NNZs: 4997, Bias: 0.851557, T: 63000000, Avg. loss: 0.678976
# Total training time: 7.38 seconds.
# -- Epoch 106
# Norm: 2.85, NNZs: 4997, Bias: 0.851005, T: 63600000, Avg. loss: 0.677080
# Total training time: 7.45 seconds.
# -- Epoch 107
# Norm: 2.85, NNZs: 4997, Bias: 0.850421, T: 64200000, Avg. loss: 0.676817
# Total training time: 7.52 seconds.
# -- Epoch 108
# Norm: 2.83, NNZs: 4997, Bias: 0.849887, T: 64800000, Avg. loss: 0.675429
# Total training time: 7.59 seconds.
# -- Epoch 109
# Norm: 2.82, NNZs: 4997, Bias: 0.849169, T: 65400000, Avg. loss: 0.675220
# Total training time: 7.67 seconds.
# -- Epoch 110
# Norm: 2.83, NNZs: 4997, Bias: 0.848519, T: 66000000, Avg. loss: 0.673814
# Total training time: 7.74 seconds.
# -- Epoch 111
# Norm: 2.80, NNZs: 4997, Bias: 0.848121, T: 66600000, Avg. loss: 0.673513
# Total training time: 7.80 seconds.
# -- Epoch 112
# Norm: 2.80, NNZs: 4997, Bias: 0.847444, T: 67200000, Avg. loss: 0.672787
# Total training time: 7.88 seconds.
# -- Epoch 113
# Norm: 2.79, NNZs: 4997, Bias: 0.847008, T: 67800000, Avg. loss: 0.672278
# Total training time: 7.96 seconds.
# -- Epoch 114
# Norm: 2.78, NNZs: 4997, Bias: 0.846498, T: 68400000, Avg. loss: 0.670918
# Total training time: 8.03 seconds.
# -- Epoch 115
# Norm: 2.79, NNZs: 4997, Bias: 0.845717, T: 69000000, Avg. loss: 0.670422
# Total training time: 8.11 seconds.
# -- Epoch 116
# Norm: 2.78, NNZs: 4997, Bias: 0.845144, T: 69600000, Avg. loss: 0.669347
# Total training time: 8.18 seconds.
# -- Epoch 117
# Norm: 2.78, NNZs: 4997, Bias: 0.844656, T: 70200000, Avg. loss: 0.668344
# Total training time: 8.26 seconds.
# -- Epoch 118
# Norm: 2.77, NNZs: 4997, Bias: 0.844163, T: 70800000, Avg. loss: 0.666919
# Total training time: 8.33 seconds.
# -- Epoch 119
# Norm: 2.75, NNZs: 4997, Bias: 0.843571, T: 71400000, Avg. loss: 0.666638
# Total training time: 8.41 seconds.
# -- Epoch 120
# Norm: 2.75, NNZs: 4997, Bias: 0.842883, T: 72000000, Avg. loss: 0.666066
# Total training time: 8.48 seconds.
# -- Epoch 121
# Norm: 2.76, NNZs: 4997, Bias: 0.842325, T: 72600000, Avg. loss: 0.665909
# Total training time: 8.55 seconds.
# -- Epoch 122
# Norm: 2.74, NNZs: 4997, Bias: 0.841817, T: 73200000, Avg. loss: 0.665114
# Total training time: 8.62 seconds.
# -- Epoch 123
# Norm: 2.74, NNZs: 4997, Bias: 0.841198, T: 73800000, Avg. loss: 0.663696
# Total training time: 8.69 seconds.
# -- Epoch 124
# Norm: 2.74, NNZs: 4997, Bias: 0.840870, T: 74400000, Avg. loss: 0.663078
# Total training time: 8.76 seconds.
# -- Epoch 125
# Norm: 2.73, NNZs: 4997, Bias: 0.840311, T: 75000000, Avg. loss: 0.662529
# Total training time: 8.83 seconds.
# -- Epoch 126
# Norm: 2.73, NNZs: 4997, Bias: 0.839812, T: 75600000, Avg. loss: 0.663085
# Total training time: 8.90 seconds.
# -- Epoch 127
# Norm: 2.72, NNZs: 4997, Bias: 0.839488, T: 76200000, Avg. loss: 0.661378
# Total training time: 8.97 seconds.
# -- Epoch 128
# Norm: 2.72, NNZs: 4997, Bias: 0.838985, T: 76800000, Avg. loss: 0.661186
# Total training time: 9.04 seconds.
# -- Epoch 129
# Norm: 2.72, NNZs: 4997, Bias: 0.838692, T: 77400000, Avg. loss: 0.659959
# Total training time: 9.11 seconds.
# -- Epoch 130
# Norm: 2.71, NNZs: 4997, Bias: 0.838079, T: 78000000, Avg. loss: 0.658796
# Total training time: 9.19 seconds.
# -- Epoch 131
# Norm: 2.70, NNZs: 4997, Bias: 0.837591, T: 78600000, Avg. loss: 0.658439
# Total training time: 9.27 seconds.
# -- Epoch 132
# Norm: 2.70, NNZs: 4997, Bias: 0.836948, T: 79200000, Avg. loss: 0.657788
# Total training time: 9.34 seconds.
# -- Epoch 133
# Norm: 2.70, NNZs: 4997, Bias: 0.836511, T: 79800000, Avg. loss: 0.657643
# Total training time: 9.42 seconds.
# -- Epoch 134
# Norm: 2.69, NNZs: 4997, Bias: 0.836061, T: 80400000, Avg. loss: 0.657362
# Total training time: 9.49 seconds.
# -- Epoch 135
# Norm: 2.69, NNZs: 4997, Bias: 0.835357, T: 81000000, Avg. loss: 0.655997
# Total training time: 9.57 seconds.
# -- Epoch 136
# Norm: 2.68, NNZs: 4997, Bias: 0.834837, T: 81600000, Avg. loss: 0.655394
# Total training time: 9.64 seconds.
# -- Epoch 137
# Norm: 2.69, NNZs: 4997, Bias: 0.834370, T: 82200000, Avg. loss: 0.654888
# Total training time: 9.72 seconds.
# -- Epoch 138
# Norm: 2.67, NNZs: 4997, Bias: 0.833934, T: 82800000, Avg. loss: 0.654895
# Total training time: 9.79 seconds.
# -- Epoch 139
# Norm: 2.67, NNZs: 4997, Bias: 0.833436, T: 83400000, Avg. loss: 0.654099
# Total training time: 9.86 seconds.
# -- Epoch 140
# Norm: 2.67, NNZs: 4997, Bias: 0.832978, T: 84000000, Avg. loss: 0.653812
# Total training time: 9.94 seconds.
# Convergence after 140 epochs took 9.94 seconds
# -- Epoch 1
# Norm: 97.72, NNZs: 4997, Bias: -6.810181, T: 600000, Avg. loss: 41.866105
# Total training time: 0.07 seconds.
# -- Epoch 2
# Norm: 51.64, NNZs: 4997, Bias: -6.763998, T: 1200000, Avg. loss: 6.343406
# Total training time: 0.13 seconds.
# -- Epoch 3
# Norm: 35.76, NNZs: 4998, Bias: -6.657239, T: 1800000, Avg. loss: 3.889265
# Total training time: 0.20 seconds.
# -- Epoch 4
# Norm: 27.60, NNZs: 4999, Bias: -6.540821, T: 2400000, Avg. loss: 2.884951
# Total training time: 0.26 seconds.
# -- Epoch 5
# Norm: 22.36, NNZs: 4999, Bias: -6.424843, T: 3000000, Avg. loss: 2.327663
# Total training time: 0.32 seconds.
# -- Epoch 6
# Norm: 18.90, NNZs: 4999, Bias: -6.311367, T: 3600000, Avg. loss: 1.964822
# Total training time: 0.39 seconds.
# -- Epoch 7
# Norm: 16.45, NNZs: 4999, Bias: -6.199640, T: 4200000, Avg. loss: 1.734208
# Total training time: 0.46 seconds.
# -- Epoch 8
# Norm: 14.79, NNZs: 4999, Bias: -6.094156, T: 4800000, Avg. loss: 1.555089
# Total training time: 0.52 seconds.
# -- Epoch 9
# Norm: 13.20, NNZs: 4999, Bias: -5.991880, T: 5400000, Avg. loss: 1.420683
# Total training time: 0.58 seconds.
# -- Epoch 10
# Norm: 12.29, NNZs: 4999, Bias: -5.892968, T: 6000000, Avg. loss: 1.316851
# Total training time: 0.65 seconds.
# -- Epoch 11
# Norm: 11.33, NNZs: 4999, Bias: -5.799915, T: 6600000, Avg. loss: 1.231192
# Total training time: 0.72 seconds.
# -- Epoch 12
# Norm: 10.58, NNZs: 4999, Bias: -5.710438, T: 7200000, Avg. loss: 1.162753
# Total training time: 0.79 seconds.
# -- Epoch 13
# Norm: 9.77, NNZs: 4999, Bias: -5.622936, T: 7800000, Avg. loss: 1.103290
# Total training time: 0.85 seconds.
# -- Epoch 14
# Norm: 9.34, NNZs: 4999, Bias: -5.540018, T: 8400000, Avg. loss: 1.054162
# Total training time: 0.91 seconds.
# -- Epoch 15
# Norm: 8.87, NNZs: 4999, Bias: -5.460205, T: 9000000, Avg. loss: 1.010111
# Total training time: 0.98 seconds.
# -- Epoch 16
# Norm: 8.41, NNZs: 4999, Bias: -5.382943, T: 9600000, Avg. loss: 0.971298
# Total training time: 1.04 seconds.
# -- Epoch 17
# Norm: 8.08, NNZs: 4999, Bias: -5.309561, T: 10200000, Avg. loss: 0.942499
# Total training time: 1.11 seconds.
# -- Epoch 18
# Norm: 7.64, NNZs: 4999, Bias: -5.237089, T: 10800000, Avg. loss: 0.908419
# Total training time: 1.18 seconds.
# -- Epoch 19
# Norm: 7.38, NNZs: 4999, Bias: -5.166651, T: 11400000, Avg. loss: 0.883114
# Total training time: 1.24 seconds.
# -- Epoch 20
# Norm: 7.08, NNZs: 4999, Bias: -5.099665, T: 12000000, Avg. loss: 0.861751
# Total training time: 1.30 seconds.
# -- Epoch 21
# Norm: 6.85, NNZs: 4999, Bias: -5.034195, T: 12600000, Avg. loss: 0.842105
# Total training time: 1.37 seconds.
# -- Epoch 22
# Norm: 6.63, NNZs: 4999, Bias: -4.971054, T: 13200000, Avg. loss: 0.820610
# Total training time: 1.43 seconds.
# -- Epoch 23
# Norm: 6.42, NNZs: 4999, Bias: -4.909721, T: 13800000, Avg. loss: 0.802250
# Total training time: 1.50 seconds.
# -- Epoch 24
# Norm: 6.23, NNZs: 4999, Bias: -4.850432, T: 14400000, Avg. loss: 0.786609
# Total training time: 1.57 seconds.
# -- Epoch 25
# Norm: 6.12, NNZs: 4999, Bias: -4.792597, T: 15000000, Avg. loss: 0.770759
# Total training time: 1.63 seconds.
# -- Epoch 26
# Norm: 5.98, NNZs: 4999, Bias: -4.736532, T: 15600000, Avg. loss: 0.759099
# Total training time: 1.70 seconds.
# -- Epoch 27
# Norm: 5.79, NNZs: 4999, Bias: -4.682656, T: 16200000, Avg. loss: 0.745321
# Total training time: 1.76 seconds.
# -- Epoch 28
# Norm: 5.64, NNZs: 4999, Bias: -4.629769, T: 16800000, Avg. loss: 0.733524
# Total training time: 1.83 seconds.
# -- Epoch 29
# Norm: 5.55, NNZs: 4999, Bias: -4.578769, T: 17400000, Avg. loss: 0.721540
# Total training time: 1.89 seconds.
# -- Epoch 30
# Norm: 5.42, NNZs: 4999, Bias: -4.528554, T: 18000000, Avg. loss: 0.712722
# Total training time: 1.96 seconds.
# -- Epoch 31
# Norm: 5.33, NNZs: 4999, Bias: -4.479752, T: 18600000, Avg. loss: 0.700665
# Total training time: 2.02 seconds.
# -- Epoch 32
# Norm: 5.19, NNZs: 4999, Bias: -4.431737, T: 19200000, Avg. loss: 0.693581
# Total training time: 2.09 seconds.
# -- Epoch 33
# Norm: 5.12, NNZs: 4999, Bias: -4.385389, T: 19800000, Avg. loss: 0.686648
# Total training time: 2.16 seconds.
# -- Epoch 34
# Norm: 4.97, NNZs: 4999, Bias: -4.339355, T: 20400000, Avg. loss: 0.676263
# Total training time: 2.22 seconds.
# -- Epoch 35
# Norm: 4.92, NNZs: 4999, Bias: -4.294873, T: 21000000, Avg. loss: 0.668890
# Total training time: 2.29 seconds.
# -- Epoch 36
# Norm: 4.85, NNZs: 4999, Bias: -4.251792, T: 21600000, Avg. loss: 0.662341
# Total training time: 2.35 seconds.
# -- Epoch 37
# Norm: 4.73, NNZs: 4999, Bias: -4.209692, T: 22200000, Avg. loss: 0.654890
# Total training time: 2.42 seconds.
# -- Epoch 38
# Norm: 4.67, NNZs: 4999, Bias: -4.168005, T: 22800000, Avg. loss: 0.648887
# Total training time: 2.48 seconds.
# -- Epoch 39
# Norm: 4.59, NNZs: 4999, Bias: -4.127965, T: 23400000, Avg. loss: 0.640777
# Total training time: 2.55 seconds.
# -- Epoch 40
# Norm: 4.50, NNZs: 4999, Bias: -4.088059, T: 24000000, Avg. loss: 0.636646
# Total training time: 2.61 seconds.
# -- Epoch 41
# Norm: 4.46, NNZs: 4999, Bias: -4.049185, T: 24600000, Avg. loss: 0.630424
# Total training time: 2.68 seconds.
# -- Epoch 42
# Norm: 4.35, NNZs: 4999, Bias: -4.011553, T: 25200000, Avg. loss: 0.626106
# Total training time: 2.75 seconds.
# -- Epoch 43
# Norm: 4.35, NNZs: 4999, Bias: -3.974347, T: 25800000, Avg. loss: 0.620444
# Total training time: 2.82 seconds.
# -- Epoch 44
# Norm: 4.27, NNZs: 4999, Bias: -3.937882, T: 26400000, Avg. loss: 0.614990
# Total training time: 2.89 seconds.
# -- Epoch 45
# Norm: 4.20, NNZs: 4999, Bias: -3.902319, T: 27000000, Avg. loss: 0.611209
# Total training time: 2.95 seconds.
# -- Epoch 46
# Norm: 4.14, NNZs: 4999, Bias: -3.867386, T: 27600000, Avg. loss: 0.605926
# Total training time: 3.02 seconds.
# -- Epoch 47
# Norm: 4.09, NNZs: 4999, Bias: -3.833082, T: 28200000, Avg. loss: 0.602503
# Total training time: 3.08 seconds.
# -- Epoch 48
# Norm: 4.07, NNZs: 4999, Bias: -3.798733, T: 28800000, Avg. loss: 0.597136
# Total training time: 3.15 seconds.
# -- Epoch 49
# Norm: 3.98, NNZs: 4999, Bias: -3.765692, T: 29400000, Avg. loss: 0.593274
# Total training time: 3.22 seconds.
# -- Epoch 50
# Norm: 3.94, NNZs: 4999, Bias: -3.733479, T: 30000000, Avg. loss: 0.589213
# Total training time: 3.28 seconds.
# -- Epoch 51
# Norm: 3.88, NNZs: 4999, Bias: -3.701622, T: 30600000, Avg. loss: 0.585069
# Total training time: 3.35 seconds.
# -- Epoch 52
# Norm: 3.86, NNZs: 4999, Bias: -3.670264, T: 31200000, Avg. loss: 0.582635
# Total training time: 3.41 seconds.
# -- Epoch 53
# Norm: 3.82, NNZs: 4999, Bias: -3.639354, T: 31800000, Avg. loss: 0.578724
# Total training time: 3.48 seconds.
# -- Epoch 54
# Norm: 3.77, NNZs: 4999, Bias: -3.609055, T: 32400000, Avg. loss: 0.575045
# Total training time: 3.55 seconds.
# -- Epoch 55
# Norm: 3.73, NNZs: 4999, Bias: -3.579323, T: 33000000, Avg. loss: 0.572608
# Total training time: 3.61 seconds.
# -- Epoch 56
# Norm: 3.71, NNZs: 4999, Bias: -3.549915, T: 33600000, Avg. loss: 0.568965
# Total training time: 3.67 seconds.
# -- Epoch 57
# Norm: 3.68, NNZs: 4999, Bias: -3.520996, T: 34200000, Avg. loss: 0.566579
# Total training time: 3.74 seconds.
# -- Epoch 58
# Norm: 3.63, NNZs: 4999, Bias: -3.492704, T: 34800000, Avg. loss: 0.563977
# Total training time: 3.81 seconds.
# -- Epoch 59
# Norm: 3.60, NNZs: 4999, Bias: -3.464641, T: 35400000, Avg. loss: 0.559751
# Total training time: 3.87 seconds.
# -- Epoch 60
# Norm: 3.56, NNZs: 4999, Bias: -3.437429, T: 36000000, Avg. loss: 0.558350
# Total training time: 3.94 seconds.
# -- Epoch 61
# Norm: 3.53, NNZs: 4999, Bias: -3.410593, T: 36600000, Avg. loss: 0.555065
# Total training time: 4.00 seconds.
# -- Epoch 62
# Norm: 3.50, NNZs: 4999, Bias: -3.383935, T: 37200000, Avg. loss: 0.552773
# Total training time: 4.07 seconds.
# -- Epoch 63
# Norm: 3.46, NNZs: 4999, Bias: -3.358085, T: 37800000, Avg. loss: 0.549607
# Total training time: 4.14 seconds.
# -- Epoch 64
# Norm: 3.44, NNZs: 4999, Bias: -3.332164, T: 38400000, Avg. loss: 0.547863
# Total training time: 4.20 seconds.
# -- Epoch 65
# Norm: 3.41, NNZs: 4999, Bias: -3.307057, T: 39000000, Avg. loss: 0.546019
# Total training time: 4.27 seconds.
# -- Epoch 66
# Norm: 3.40, NNZs: 4999, Bias: -3.282132, T: 39600000, Avg. loss: 0.543352
# Total training time: 4.33 seconds.
# -- Epoch 67
# Norm: 3.37, NNZs: 4999, Bias: -3.257770, T: 40200000, Avg. loss: 0.540066
# Total training time: 4.40 seconds.
# -- Epoch 68
# Norm: 3.32, NNZs: 4999, Bias: -3.233786, T: 40800000, Avg. loss: 0.538968
# Total training time: 4.46 seconds.
# -- Epoch 69
# Norm: 3.29, NNZs: 4999, Bias: -3.210204, T: 41400000, Avg. loss: 0.535853
# Total training time: 4.52 seconds.
# -- Epoch 70
# Norm: 3.28, NNZs: 4999, Bias: -3.186853, T: 42000000, Avg. loss: 0.534009
# Total training time: 4.59 seconds.
# -- Epoch 71
# Norm: 3.25, NNZs: 4999, Bias: -3.163598, T: 42600000, Avg. loss: 0.533115
# Total training time: 4.66 seconds.
# -- Epoch 72
# Norm: 3.21, NNZs: 4999, Bias: -3.141049, T: 43200000, Avg. loss: 0.530129
# Total training time: 4.72 seconds.
# -- Epoch 73
# Norm: 3.19, NNZs: 4999, Bias: -3.118550, T: 43800000, Avg. loss: 0.527880
# Total training time: 4.79 seconds.
# -- Epoch 74
# Norm: 3.17, NNZs: 4999, Bias: -3.096645, T: 44400000, Avg. loss: 0.525954
# Total training time: 4.86 seconds.
# -- Epoch 75
# Norm: 3.16, NNZs: 4999, Bias: -3.074711, T: 45000000, Avg. loss: 0.525524
# Total training time: 4.92 seconds.
# -- Epoch 76
# Norm: 3.12, NNZs: 4999, Bias: -3.053485, T: 45600000, Avg. loss: 0.522670
# Total training time: 4.99 seconds.
# -- Epoch 77
# Norm: 3.10, NNZs: 4999, Bias: -3.032464, T: 46200000, Avg. loss: 0.520226
# Total training time: 5.05 seconds.
# -- Epoch 78
# Norm: 3.07, NNZs: 4999, Bias: -3.011733, T: 46800000, Avg. loss: 0.519657
# Total training time: 5.12 seconds.
# -- Epoch 79
# Norm: 3.06, NNZs: 4999, Bias: -2.991081, T: 47400000, Avg. loss: 0.517217
# Total training time: 5.19 seconds.
# -- Epoch 80
# Norm: 3.06, NNZs: 4999, Bias: -2.970802, T: 48000000, Avg. loss: 0.516103
# Total training time: 5.25 seconds.
# -- Epoch 81
# Norm: 3.03, NNZs: 4999, Bias: -2.950846, T: 48600000, Avg. loss: 0.514598
# Total training time: 5.32 seconds.
# -- Epoch 82
# Norm: 3.00, NNZs: 4999, Bias: -2.931117, T: 49200000, Avg. loss: 0.513249
# Total training time: 5.39 seconds.
# -- Epoch 83
# Norm: 2.98, NNZs: 4999, Bias: -2.911806, T: 49800000, Avg. loss: 0.512042
# Total training time: 5.45 seconds.
# -- Epoch 84
# Norm: 2.97, NNZs: 4999, Bias: -2.892441, T: 50400000, Avg. loss: 0.509638
# Total training time: 5.51 seconds.
# -- Epoch 85
# Norm: 2.95, NNZs: 4999, Bias: -2.873642, T: 51000000, Avg. loss: 0.508762
# Total training time: 5.58 seconds.
# -- Epoch 86
# Norm: 2.92, NNZs: 4999, Bias: -2.854951, T: 51600000, Avg. loss: 0.507644
# Total training time: 5.65 seconds.
# -- Epoch 87
# Norm: 2.91, NNZs: 4999, Bias: -2.836593, T: 52200000, Avg. loss: 0.505675
# Total training time: 5.72 seconds.
# -- Epoch 88
# Norm: 2.90, NNZs: 4999, Bias: -2.818486, T: 52800000, Avg. loss: 0.504283
# Total training time: 5.79 seconds.
# -- Epoch 89
# Norm: 2.88, NNZs: 4999, Bias: -2.800520, T: 53400000, Avg. loss: 0.503907
# Total training time: 5.85 seconds.
# -- Epoch 90
# Norm: 2.86, NNZs: 4999, Bias: -2.782813, T: 54000000, Avg. loss: 0.501902
# Total training time: 5.92 seconds.
# -- Epoch 91
# Norm: 2.86, NNZs: 4999, Bias: -2.765341, T: 54600000, Avg. loss: 0.500768
# Total training time: 5.99 seconds.
# -- Epoch 92
# Norm: 2.83, NNZs: 4999, Bias: -2.747959, T: 55200000, Avg. loss: 0.499817
# Total training time: 6.05 seconds.
# -- Epoch 93
# Norm: 2.81, NNZs: 4999, Bias: -2.730894, T: 55800000, Avg. loss: 0.497783
# Total training time: 6.12 seconds.
# -- Epoch 94
# Norm: 2.80, NNZs: 4999, Bias: -2.714144, T: 56400000, Avg. loss: 0.496958
# Total training time: 6.18 seconds.
# -- Epoch 95
# Norm: 2.78, NNZs: 4999, Bias: -2.697657, T: 57000000, Avg. loss: 0.496346
# Total training time: 6.25 seconds.
# -- Epoch 96
# Norm: 2.76, NNZs: 4999, Bias: -2.681239, T: 57600000, Avg. loss: 0.494565
# Total training time: 6.31 seconds.
# -- Epoch 97
# Norm: 2.74, NNZs: 4999, Bias: -2.665181, T: 58200000, Avg. loss: 0.493081
# Total training time: 6.38 seconds.
# -- Epoch 98
# Norm: 2.73, NNZs: 4999, Bias: -2.649267, T: 58800000, Avg. loss: 0.492000
# Total training time: 6.45 seconds.
# -- Epoch 99
# Norm: 2.72, NNZs: 4999, Bias: -2.633483, T: 59400000, Avg. loss: 0.490527
# Total training time: 6.51 seconds.
# -- Epoch 100
# Norm: 2.71, NNZs: 4999, Bias: -2.617805, T: 60000000, Avg. loss: 0.490367
# Total training time: 6.58 seconds.
# -- Epoch 101
# Norm: 2.70, NNZs: 4999, Bias: -2.602525, T: 60600000, Avg. loss: 0.488696
# Total training time: 6.64 seconds.
# -- Epoch 102
# Norm: 2.67, NNZs: 4999, Bias: -2.587328, T: 61200000, Avg. loss: 0.488111
# Total training time: 6.71 seconds.
# -- Epoch 103
# Norm: 2.67, NNZs: 4999, Bias: -2.572331, T: 61800000, Avg. loss: 0.487071
# Total training time: 6.78 seconds.
# -- Epoch 104
# Norm: 2.65, NNZs: 4999, Bias: -2.557510, T: 62400000, Avg. loss: 0.486117
# Total training time: 6.84 seconds.
# -- Epoch 105
# Norm: 2.63, NNZs: 4999, Bias: -2.542732, T: 63000000, Avg. loss: 0.485840
# Total training time: 6.91 seconds.
# -- Epoch 106
# Norm: 2.63, NNZs: 4999, Bias: -2.528220, T: 63600000, Avg. loss: 0.483692
# Total training time: 6.97 seconds.
# -- Epoch 107
# Norm: 2.60, NNZs: 4999, Bias: -2.513958, T: 64200000, Avg. loss: 0.482828
# Total training time: 7.04 seconds.
# -- Epoch 108
# Norm: 2.59, NNZs: 4999, Bias: -2.499780, T: 64800000, Avg. loss: 0.482607
# Total training time: 7.11 seconds.
# -- Epoch 109
# Norm: 2.59, NNZs: 4999, Bias: -2.485660, T: 65400000, Avg. loss: 0.481253
# Total training time: 7.17 seconds.
# -- Epoch 110
# Norm: 2.56, NNZs: 4999, Bias: -2.471956, T: 66000000, Avg. loss: 0.480247
# Total training time: 7.24 seconds.
# -- Epoch 111
# Norm: 2.56, NNZs: 4999, Bias: -2.458264, T: 66600000, Avg. loss: 0.478975
# Total training time: 7.30 seconds.
# -- Epoch 112
# Norm: 2.55, NNZs: 4999, Bias: -2.444759, T: 67200000, Avg. loss: 0.478925
# Total training time: 7.37 seconds.
# -- Epoch 113
# Norm: 2.54, NNZs: 4999, Bias: -2.431274, T: 67800000, Avg. loss: 0.477858
# Total training time: 7.43 seconds.
# -- Epoch 114
# Norm: 2.52, NNZs: 4999, Bias: -2.418054, T: 68400000, Avg. loss: 0.476940
# Total training time: 7.50 seconds.
# -- Epoch 115
# Norm: 2.52, NNZs: 4999, Bias: -2.404845, T: 69000000, Avg. loss: 0.476098
# Total training time: 7.57 seconds.
# -- Epoch 116
# Norm: 2.49, NNZs: 4999, Bias: -2.391905, T: 69600000, Avg. loss: 0.475409
# Total training time: 7.63 seconds.
# -- Epoch 117
# Norm: 2.49, NNZs: 4999, Bias: -2.379244, T: 70200000, Avg. loss: 0.474818
# Total training time: 7.69 seconds.
# -- Epoch 118
# Norm: 2.48, NNZs: 4999, Bias: -2.366567, T: 70800000, Avg. loss: 0.473989
# Total training time: 7.76 seconds.
# Convergence after 118 epochs took 7.76 seconds
# Best parameters: {'alpha': 0.0001, 'learning_rate': 'optimal', 'penalty': 'l2'}

# %%
# best linear svm model
svm_model = SGDClassifier(
    loss="hinge",        # hinge loss = linear SVM
    max_iter=1000,
    tol=1e-3,
    alpha=0.0001,
    learning_rate='optimal',
    penalty='l2'
)

svm_model.fit(X_train_scaled, y_bal)
# Out:
# SGDClassifier()

# %%
# Add svm model
# Load existing models
models = joblib.load("all_models.pkl")

# Add new model
models["LinearSVC"] = svm_model


# 3. Save back to the same file
joblib.dump(models, "all_models.pkl")
# Out:
# ['all_models.pkl']

# %%
# # Evaluate nb model
y_pred_svm = svm_model.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Classification Report:\n", classification_report(y_test, y_pred_svm))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_svm))
# Out:
# Accuracy: 0.7634125570953008
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.67      0.73      0.70     33840
#      neutral       0.09      0.38      0.14      9045
#     positive       0.96      0.79      0.86    189621
#
#     accuracy                           0.76    232506
#    macro avg       0.57      0.63      0.57    232506
# weighted avg       0.88      0.76      0.81    232506
#
# Confusion Matrix:
#  [[ 24596   5967   3277]
#  [  2324   3426   3295]
#  [  9774  30371 149476]]

# %% [markdown]
# #### Comparing baseline model against linear SVC model
# Baseline model had a prediction accuracy of **0.78**, while the SVM model had a prediction accuracy of 0.76. Hence, baseline model is still better.

# %% [markdown]
# ## Summary of Model Evaluation

# %%
# Comparing all models
scoring = {
    'accuracy': 'accuracy',
    'f1_macro': 'f1_macro',  # macro-average for multi-class or imbalanced
}

for name, model in models.items():
    scores = cross_validate(model, X_train_scaled, y_bal, scoring=scoring, cv=5, n_jobs=-1)
    print(f"{name} mean F1: {scores['test_f1_macro'].mean():.4f}, mean Accuracy: {scores['test_accuracy'].mean():.4f}")
# Out:
# logistic mean F1: 0.6954, mean Accuracy: 0.6968
# LinearSVC mean F1: 0.6767, mean Accuracy: 0.6781
# naives_baye mean F1: 0.6515, mean Accuracy: 0.6573

# %% [markdown]
# Logistic Regression remains to outperform both LinearSVC model and Naives Baye model, hence it will be used for sentiment analysis.
